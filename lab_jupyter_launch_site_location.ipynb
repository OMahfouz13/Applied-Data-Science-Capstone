# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab: Interactive Visual Analytics with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
#
# *   **TASK 1:** Mark all launch sites on a map
# *   **TASK 2:** Mark the success/failed launches for each site on the map
# *   **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
import piplite
await piplite.install(['folium'])
await piplite.install(['pandas'])

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/v4/DV0101EN-Exercise-Generating-Maps-in-Python.ipynb)

# %%
## Task 1: Mark all launch sites on a map

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df=pd.read_csv(spacex_csv_file)

# %%
launch_sites = spacex_df['Launch Site'].unique()

# %%
low, high = (0,10000)
mask = (spacex_df['Payload Mass (kg)'] > low) & (spacex_df['Payload Mass (kg)'] < high)
df_mask = spacex_df[mask]
df_mask[df_mask['Launch Site']==launch_sites[0]]
# Out:
#     Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 2               3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3               4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4               5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
# 5               7  2013-12-03   22:41:00         F9 v1.1  CCAFS LC-40
# 6               8  2014-01-06   22:06:00         F9 v1.1  CCAFS LC-40
# 7               9  2014-04-18   19:25:00         F9 v1.1  CCAFS LC-40
# 8              10  2014-07-14   15:15:00         F9 v1.1  CCAFS LC-40
# 9              11  2014-08-05    8:00:00         F9 v1.1  CCAFS LC-40
# 10             12  2014-09-07    5:00:00   F9 v1.1 B1011  CCAFS LC-40
# 11             13  2014-09-21    5:52:00   F9 v1.1 B1010  CCAFS LC-40
# 12             14  2015-01-10    9:47:00   F9 v1.1 B1012  CCAFS LC-40
# 13             15  2015-02-11   23:03:00   F9 v1.1 B1013  CCAFS LC-40
# 14             16  2015-03-02    3:50:00   F9 v1.1 B1014  CCAFS LC-40
# 15             17  2015-04-14   20:10:00   F9 v1.1 B1015  CCAFS LC-40
# 16             18  2015-04-27   23:03:00   F9 v1.1 B1016  CCAFS LC-40
# 17             19  2015-06-28   14:21:00   F9 v1.1 B1018  CCAFS LC-40
# 18             20  2015-12-22    1:29:00     F9 FT B1019  CCAFS LC-40
# 19             22  2016-03-04   23:35:00     F9 FT B1020  CCAFS LC-40
# 20             23  2016-04-08   20:43:00   F9 FT B1021.1  CCAFS LC-40
# 21             24  2016-05-06    5:21:00     F9 FT B1022  CCAFS LC-40
# 22             25  2016-05-27   21:39:00   F9 FT B1023.1  CCAFS LC-40
# 23             26  2016-06-15   14:29:00     F9 FT B1024  CCAFS LC-40
# 24             27  2016-07-18    4:45:00   F9 FT B1025.1  CCAFS LC-40
# 25             28  2016-08-14    5:26:00     F9 FT B1026  CCAFS LC-40
#
#                                       Payload  Payload Mass (kg)  \
# 2                      Dragon demo flight C2+              525.0
# 3                                SpaceX CRS-1              500.0
# 4                                SpaceX CRS-2              677.0
# 5                                       SES-8             3170.0
# 6                                   Thaicom 6             3325.0
# 7                                SpaceX CRS-3             2296.0
# 8     OG2 Mission 1  6 Orbcomm-OG2 satellites             1316.0
# 9                                   AsiaSat 8             4535.0
# 10                                  AsiaSat 6             4428.0
# 11                               SpaceX CRS-4             2216.0
# 12                               SpaceX CRS-5             2395.0
# 13                                     DSCOVR              570.0
# 14                 ABS-3A Eutelsat 115 West B             4159.0
# 15                               SpaceX CRS-6             1898.0
# 16               TürkmenÄlem 52°E / MonacoSAT             4707.0
# 17                               SpaceX CRS-7             1952.0
# 18  OG2 Mission 2   11 Orbcomm-OG2 satellites             2034.0
# 19                                      SES-9             5271.0
# 20                               SpaceX CRS-8             3136.0
# 21                                   JCSAT-14             4696.0
# 22                                  Thaicom 8             3100.0
# 23                 ABS-2A Eutelsat 117 West B             3600.0
# 24                               SpaceX CRS-9             2257.0
# 25                                   JCSAT-16             4600.0
#
#            Orbit                            Customer          Landing Outcome  \
# 2      LEO (ISS)                         NASA (COTS)               No attempt
# 3      LEO (ISS)                          NASA (CRS)               No attempt
# 4      LEO (ISS)                          NASA (CRS)               No attempt
# 5            GTO                                 SES               No attempt
# 6            GTO                             Thaicom               No attempt
# 7      LEO (ISS)                          NASA (CRS)       Controlled (ocean)
# 8            LEO                             Orbcomm       Controlled (ocean)
# 9            GTO                             AsiaSat               No attempt
# 10           GTO                             AsiaSat               No attempt
# 11     LEO (ISS)                          NASA (CRS)     Uncontrolled (ocean)
# 12     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 13  Sun–Earth L1            U.S. Air Force NASA NOAA       Controlled (ocean)
# 14           GTO                        ABS Eutelsat               No attempt
# 15     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 16           GTO  Turkmenistan National Space Agency               No attempt
# 17     LEO (ISS)                          NASA (CRS)  Precluded  (drone ship)
# 18           LEO                             Orbcomm    Success  (ground pad)
# 19           GTO                                 SES     Failure (drone ship)
# 20     LEO (ISS)                          NASA (CRS)    Success  (drone ship)
# 21           GTO              SKY Perfect JSAT Group     Success (drone ship)
# 22           GTO                             Thaicom    Success  (drone ship)
# 23           GTO                        ABS Eutelsat    Failure  (drone ship)
# 24     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 25           GTO              SKY Perfect JSAT Group     Success (drone ship)
#
#     class        Lat       Long
# 2       0  28.562302 -80.577356
# 3       0  28.562302 -80.577356
# 4       0  28.562302 -80.577356
# 5       0  28.562302 -80.577356
# 6       0  28.562302 -80.577356
# 7       0  28.562302 -80.577356
# 8       0  28.562302 -80.577356
# 9       0  28.562302 -80.577356
# 10      0  28.562302 -80.577356
# 11      0  28.562302 -80.577356
# 12      0  28.562302 -80.577356
# 13      0  28.562302 -80.577356
# 14      0  28.562302 -80.577356
# 15      0  28.562302 -80.577356
# 16      0  28.562302 -80.577356
# 17      1  28.562302 -80.577356
# 18      1  28.562302 -80.577356
# 19      0  28.562302 -80.577356
# 20      1  28.562302 -80.577356
# 21      1  28.562302 -80.577356
# 22      1  28.562302 -80.577356
# 23      0  28.562302 -80.577356
# 24      1  28.562302 -80.577356
# 25      1  28.562302 -80.577356

# %%
filtered_df = spacex_df.groupby('Launch Site')['class'].value_counts().reset_index()
filtered_df[filtered_df['Launch Site']== launch_sites[1]]
# Out:
#    Launch Site  class  count
# 6  VAFB SLC-4E      0      6
# 7  VAFB SLC-4E      1      4

# %%
payload_df = spacex_df.groupby('Launch Site')['class'].sum().reset_index()
# Out:
#     Launch Site  class
# 0   CCAFS LC-40      7
# 1  CCAFS SLC-40      3
# 2    KSC LC-39A     10
# 3   VAFB SLC-4E      4

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_675125db23ebcd16fb05f21e3af00de7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_675125db23ebcd16fb05f21e3af00de7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_675125db23ebcd16fb05f21e3af00de7 = L.map(
#                 &quot;map_675125db23ebcd16fb05f21e3af00de7&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_533eabab59dc997b3c763e77284fe4bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_533eabab59dc997b3c763e77284fe4bf.addTo(map_675125db23ebcd16fb05f21e3af00de7);
#
#
#             var circle_354609f6a88db5d495a16fbeced06f65 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_675125db23ebcd16fb05f21e3af00de7);
#
#
#         var popup_662dc3e8c29eb4e4955738d5d4c85e69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_735d6fd4d2c0fd81af7677ff929cfa4a = $(`&lt;div id=&quot;html_735d6fd4d2c0fd81af7677ff929cfa4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_662dc3e8c29eb4e4955738d5d4c85e69.setContent(html_735d6fd4d2c0fd81af7677ff929cfa4a);
#
#
#
#         circle_354609f6a88db5d495a16fbeced06f65.bindPopup(popup_662dc3e8c29eb4e4955738d5d4c85e69)
#         ;
#
#
#
#
#             var marker_4809446ca7780ee292a4f0d3537f5893 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_675125db23ebcd16fb05f21e3af00de7);
#
#
#             var div_icon_382b725bbe1d9dfba65942f538325966 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4809446ca7780ee292a4f0d3537f5893.setIcon(div_icon_382b725bbe1d9dfba65942f538325966);
#
#
#                 marker_4809446ca7780ee292a4f0d3537f5893.setIcon(div_icon_382b725bbe1d9dfba65942f538325966);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# *TODO:*  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
launch_sites = folium.map.FeatureGroup()
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label
for lat, lng, label in zip (launch_sites_df['Lat'],launch_sites_df['Long'], launch_sites_df['Launch Site']):
    launch_sites.add_child(
        folium.vector_layers.CircleMarker(
            [lat,lng],
            radius =5,
            color = '#d35400',
            fill = True,
            fill_opacity = 0.6,
            popup = label

        )
    )
site_map.add_child(launch_sites)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5257a0a1979c7ac6938aacf1f391fac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5257a0a1979c7ac6938aacf1f391fac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5257a0a1979c7ac6938aacf1f391fac8 = L.map(
#                 &quot;map_5257a0a1979c7ac6938aacf1f391fac8&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5622059a4170d49c0a4a7c157fe3dd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5622059a4170d49c0a4a7c157fe3dd3.addTo(map_5257a0a1979c7ac6938aacf1f391fac8);
#
#
#             var feature_group_6a046c5ff8a451c7429c5d409e6dcf67 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_7a0fed1759b47a6abf22c7c55132f64b = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_6a046c5ff8a451c7429c5d409e6dcf67);
#
#
#         var popup_1bfb1e551e36811ac613310ff9cb56be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff864bd889e9ef2f6de8c59d417cf4c0 = $(`&lt;div id=&quot;html_ff864bd889e9ef2f6de8c59d417cf4c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_1bfb1e551e36811ac613310ff9cb56be.setContent(html_ff864bd889e9ef2f6de8c59d417cf4c0);
#
#
#
#         circle_marker_7a0fed1759b47a6abf22c7c55132f64b.bindPopup(popup_1bfb1e551e36811ac613310ff9cb56be)
#         ;
#
#
#
#
#             var circle_marker_f326bb8f29fb79eb8b953a1853ab840b = L.circleMarker(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_6a046c5ff8a451c7429c5d409e6dcf67);
#
#
#         var popup_d136135a80c8c497e6437754f347f5d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51d1f9318fc578b2459ea06069b39da8 = $(`&lt;div id=&quot;html_51d1f9318fc578b2459ea06069b39da8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_d136135a80c8c497e6437754f347f5d7.setContent(html_51d1f9318fc578b2459ea06069b39da8);
#
#
#
#         circle_marker_f326bb8f29fb79eb8b953a1853ab840b.bindPopup(popup_d136135a80c8c497e6437754f347f5d7)
#         ;
#
#
#
#
#             var circle_marker_9b5ebbbff0a639b7410cf15eacd66bd9 = L.circleMarker(
#                 [28.57325457, -80.64689529],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_6a046c5ff8a451c7429c5d409e6dcf67);
#
#
#         var popup_af0c16424e6686bc782f2ef367256792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d88bdf456c0e960ff98383b84f11220 = $(`&lt;div id=&quot;html_8d88bdf456c0e960ff98383b84f11220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_af0c16424e6686bc782f2ef367256792.setContent(html_8d88bdf456c0e960ff98383b84f11220);
#
#
#
#         circle_marker_9b5ebbbff0a639b7410cf15eacd66bd9.bindPopup(popup_af0c16424e6686bc782f2ef367256792)
#         ;
#
#
#
#
#             var circle_marker_4d08f0c4cc0d48b67e1757c5b3df7bf7 = L.circleMarker(
#                 [34.63283416

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
#
# *   Are all launch sites in proximity to the Equator line?
# *   Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %%
spacex_df.tail()
# Out:
#      Launch Site        Lat      Long  class
# 51  CCAFS SLC-40  28.563197 -80.57682      0
# 52  CCAFS SLC-40  28.563197 -80.57682      0
# 53  CCAFS SLC-40  28.563197 -80.57682      0
# 54  CCAFS SLC-40  28.563197 -80.57682      1
# 55  CCAFS SLC-40  28.563197 -80.57682      0

# %%
# Task 2: Mark the success/failed launches for each site on the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
launch_sites = folium.map.FeatureGroup()
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label
for lat, lng, label, success in zip (spacex_df['Lat'],spacex_df['Long'], spacex_df['Launch Site'], spacex_df['class']):
    if success == 1:
        color = 'green'
    else:
        color = 'red'
    launch_sites.add_child(
        folium.vector_layers.CircleMarker(
            [lat,lng],
            radius =5,
            color = color,
            fill = True,
            fill_opacity = 0.6,
            popup = label

        )
    )
site_map.add_child(launch_sites)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22b22b39b8acb89a2a779907ceae9bf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22b22b39b8acb89a2a779907ceae9bf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22b22b39b8acb89a2a779907ceae9bf3 = L.map(
#                 &quot;map_22b22b39b8acb89a2a779907ceae9bf3&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c46679ee3a230e29d2b7b8a7f2696e49 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c46679ee3a230e29d2b7b8a7f2696e49.addTo(map_22b22b39b8acb89a2a779907ceae9bf3);
#
#
#             var feature_group_1193a8e7936d77f69cc79c0fae73aa54 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_fb142561e1a2295e2284a1fc639b95ba = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1193a8e7936d77f69cc79c0fae73aa54);
#
#
#         var popup_0522cb1962ab6428cea062085961ac58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e743724597c5ebd7bc2a9d8af95768 = $(`&lt;div id=&quot;html_d0e743724597c5ebd7bc2a9d8af95768&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_0522cb1962ab6428cea062085961ac58.setContent(html_d0e743724597c5ebd7bc2a9d8af95768);
#
#
#
#         circle_marker_fb142561e1a2295e2284a1fc639b95ba.bindPopup(popup_0522cb1962ab6428cea062085961ac58)
#         ;
#
#
#
#
#             var circle_marker_6c73356c2f98ac3671e623cc3c85a553 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1193a8e7936d77f69cc79c0fae73aa54);
#
#
#         var popup_113d75ed3a119343d9034494c0d4dd66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da3d9d8ce572eb36dfb0e5aa4dbe36ac = $(`&lt;div id=&quot;html_da3d9d8ce572eb36dfb0e5aa4dbe36ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_113d75ed3a119343d9034494c0d4dd66.setContent(html_da3d9d8ce572eb36dfb0e5aa4dbe36ac);
#
#
#
#         circle_marker_6c73356c2f98ac3671e623cc3c85a553.bindPopup(popup_113d75ed3a119343d9034494c0d4dd66)
#         ;
#
#
#
#
#             var circle_marker_75deead982ca94d67920791b78e003e2 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1193a8e7936d77f69cc79c0fae73aa54);
#
#
#         var popup_08d889689678213ac877eba656ef711e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2493b10c3f742e4c2005e3a768a90dc1 = $(`&lt;div id=&quot;html_2493b10c3f742e4c2005e3a768a90dc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_08d889689678213ac877eba656ef711e.setContent(html_2493b10c3f742e4c2005e3a768a90dc1);
#
#
#
#         circle_marker_75deead982ca94d67920791b78e003e2.bindPopup(popup_08d889689678213ac877eba656ef711e)
#         ;
#
#
#
#
#             var circle_marker_be1127e6ed2237aeb36ce458caf2dea3 = L.circleMarker(
#                 [28.56230197, -80.57735648],

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# *TODO:* Create a new column in `spacex_df` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red
def check_color(value):
    if value == 1:
        color = 'green'
    else:
        color = 'red'
    return color

spacex_df['marker_color'] = spacex_df['class'].apply(lambda x: check_color(x))

spacex_df.head()
# Out:
#    Launch Site        Lat       Long  class marker_color
# 0  CCAFS LC-40  28.562302 -80.577356      0          red
# 1  CCAFS LC-40  28.562302 -80.577356      0          red
# 2  CCAFS LC-40  28.562302 -80.577356      0          red
# 3  CCAFS LC-40  28.562302 -80.577356      0          red
# 4  CCAFS LC-40  28.562302 -80.577356      0          red

# %%
#*TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

for lat, lng, label, color in zip(spacex_df['Lat'],spacex_df['Long'], spacex_df['Launch Site'], spacex_df['marker_color']):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
        color = color
    ).add_to(marker_cluster)
site_map.add_child(marker_cluster)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /lib/python3.12/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File /lib/python3.12/site-packages/folium/folium.py:335, in Map._repr_html_(self, **kwargs)
#     333     self._parent = None
#     334 else:
# --> 335     out = self._parent._repr_html_(**kwargs)
#     336 return out
#
# File /lib/python3.12/site-packages/branca/element.py:410, in Figure._repr_html_(self, **kwargs)
#     408 def _repr_html_(self, **kwargs) -> str:
#     409     """Displays the Figure in a Jupyter notebook."""
# --> 410     html = escape(self.render(**kwargs))
#     411     if self.height is None:
#     412         iframe = (
#     413             '<div style="width:{width};">'
#     414             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     420             "</div></div>"
#     421         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File /lib/python3.12/site-packages/branca/element.py:405, in Figure.render(self, **kwargs)
#     403 """Renders the HTML representation of the element."""
#     404 for name, child in self._children.items():
# --> 405     child.render(**kwargs)
#     406 return self._template.render(this=self, kwargs=kwargs)
#
# File /lib/python3.12/site-packages/folium/folium.py:417, in Map.render(self, **kwargs)
#     390 figure.header.add_child(
#     391     Element(
#     392         "<style>html, body {"
#    (...)
#     400     name="css_style",
#     401 )
#     403 figure.header.add_child(
#     404     Element(
#     405         "<style>#map {"
#    (...)
#     414     name="map_style",
#     415 )
# --> 417 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/elements.py:33, in JSCSSMixin.render(self, **kwargs)
#      30 for name, url in self.default_css:
#      31     figure.header.add_child(CssLink(url), name=name)
# ---> 33 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/branca/element.py:736, in MacroElement.render(self, **kwargs)
#     733     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     735 for name, element in self._children.items():
# --> 736     element.render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/elements.py:33, in JSCSSMixin.render(self, **kwargs)
#      30 for name, url in self.default_css:
#      31     figure.header.add_child(CssLink(url), name=name)
# ---> 33 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/map.py:90, in Layer.render(self, **kwargs)
#      82 if self.show:
#      83     self.add_child(
#      84         ElementAddToElement(
#      85             element_name=self.get_name(),
#    (...)
#      88         name=self.get_name() + "_add",
#      89     )
# ---> 90 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/branca/element.py:736, in MacroElement.render(self, **kwargs)
#     733     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     735 for name, element in self._children.items():
# --> 736     element.render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/map.py:428, in Marker.render(self)
#     426 def render(self):
#     427     if self.location is None:
# --> 428         raise ValueError(
#     429             f"{self._name} location must be assigned when added directly to map."
#     430         )
#     431     if self.icon:
#     432         self.add_child(self.SetIcon(marker=self, icon=self.icon))
#
# ValueError: Marker location must be assigned when added directly to map.

# %%
for index, record in spacex_df.iterrows():
    print (record['Lat'],record['Long'])
# Out:
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 28.56230197 -80.57735648
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 34.63283416 -120.6107455
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.57325457 -80.64689529
# 28.56319718 -80.57682003
# 28.56319718 -80.57682003
# 28.56319718 -80.57682003
# 28.56319718 -80.57682003
# 28.56319718 -80.57682003
# 28.56319718 -80.57682003
# 28.56319718 -80.57682003

# %%
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    markers = folium.Marker(
        location = (record['Lat'], record['Long']),
        icon=folium.Icon(color = 'white', icon_color = record['marker_color']),
        popup=[record['Launch Site'], record['class']]
        
    )
    marker_cluster.add_child(markers)

site_map.add_child(marker_cluster)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /lib/python3.12/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File /lib/python3.12/site-packages/folium/folium.py:335, in Map._repr_html_(self, **kwargs)
#     333     self._parent = None
#     334 else:
# --> 335     out = self._parent._repr_html_(**kwargs)
#     336 return out
#
# File /lib/python3.12/site-packages/branca/element.py:410, in Figure._repr_html_(self, **kwargs)
#     408 def _repr_html_(self, **kwargs) -> str:
#     409     """Displays the Figure in a Jupyter notebook."""
# --> 410     html = escape(self.render(**kwargs))
#     411     if self.height is None:
#     412         iframe = (
#     413             '<div style="width:{width};">'
#     414             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     420             "</div></div>"
#     421         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File /lib/python3.12/site-packages/branca/element.py:405, in Figure.render(self, **kwargs)
#     403 """Renders the HTML representation of the element."""
#     404 for name, child in self._children.items():
# --> 405     child.render(**kwargs)
#     406 return self._template.render(this=self, kwargs=kwargs)
#
# File /lib/python3.12/site-packages/folium/folium.py:417, in Map.render(self, **kwargs)
#     390 figure.header.add_child(
#     391     Element(
#     392         "<style>html, body {"
#    (...)
#     400     name="css_style",
#     401 )
#     403 figure.header.add_child(
#     404     Element(
#     405         "<style>#map {"
#    (...)
#     414     name="map_style",
#     415 )
# --> 417 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/elements.py:33, in JSCSSMixin.render(self, **kwargs)
#      30 for name, url in self.default_css:
#      31     figure.header.add_child(CssLink(url), name=name)
# ---> 33 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/branca/element.py:736, in MacroElement.render(self, **kwargs)
#     733     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     735 for name, element in self._children.items():
# --> 736     element.render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/elements.py:33, in JSCSSMixin.render(self, **kwargs)
#      30 for name, url in self.default_css:
#      31     figure.header.add_child(CssLink(url), name=name)
# ---> 33 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/map.py:90, in Layer.render(self, **kwargs)
#      82 if self.show:
#      83     self.add_child(
#      84         ElementAddToElement(
#      85             element_name=self.get_name(),
#    (...)
#      88         name=self.get_name() + "_add",
#      89     )
# ---> 90 super().render(**kwargs)
#
# File /lib/python3.12/site-packages/branca/element.py:736, in MacroElement.render(self, **kwargs)
#     733     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     735 for name, element in self._children.items():
# --> 736     element.render(**kwargs)
#
# File /lib/python3.12/site-packages/folium/map.py:428, in Marker.render(self)
#     426 def render(self):
#     427     if self.location is None:
# --> 428         raise ValueError(
#     429             f"{self._name} location must be assigned when added directly to map."
#     430         )
#     431     if self.icon:
#     432         self.add_child(self.SetIcon(marker=self, icon=self.icon))
#
# ValueError: Marker location must be assigned when added directly to map.

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)

# instantiate a mark cluster object for the incidents in the dataframe
marker_cluster = plugins.MarkerCluster().add_to(site_map)

# loop through the dataframe and add each data point to the mark cluster
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    markers = folium.Marker(
        location = (record['Lat'], record['Long']),
        icon=folium.Icon(color = 'white', icon_color = record['marker_color']),
        popup=[record['Launch Site'], record['class']]
        
    ).add_to(marker_cluster)


# display map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc0d8bf49ce4d471ff2bea3db0b5a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc0d8bf49ce4d471ff2bea3db0b5a5b = L.map(
#                 &quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce454816d4a245021426683bb5b1f23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce454816d4a245021426683bb5b1f23d.addTo(map_0dc0d8bf49ce4d471ff2bea3db0b5a5b);
#
#
#             var marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_977b1345a52abb87489ceb4b5cc44183 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_1e3b2146ca5b411ef0f542a54f123edd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad418f9c7e229eb7445a02e3c2cf2c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_414b01a7d2a4274de3bbbfbfc0fbce9f = $(`&lt;div id=&quot;html_414b01a7d2a4274de3bbbfbfc0fbce9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_ad418f9c7e229eb7445a02e3c2cf2c9f.setContent(html_414b01a7d2a4274de3bbbfbfc0fbce9f);
#
#
#
#         marker_977b1345a52abb87489ceb4b5cc44183.bindPopup(popup_ad418f9c7e229eb7445a02e3c2cf2c9f)
#         ;
#
#
#
#
#                 marker_977b1345a52abb87489ceb4b5cc44183.setIcon(icon_1e3b2146ca5b411ef0f542a54f123edd);
#
#
#             var marker_1a56450ce69a48e75a90201f961f71a4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_3089aeb02559b4e6221e208c8fa43245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c26fadbb5a3d5a34aadb2a09df7a98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df75d921d263529f54a27229a2e2e2ea = $(`&lt;div id=&quot;html_df75d921d263529f54a27229a2e2e2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_c26fadbb5a3d5a34aadb2a09df7a98ec.setContent(html_df75d921d263529f54a27229a2e2e2ea);
#
#
#
#         marker_1a56450ce69a48e75a90201f961f71a4.bindPopup(popup_c26fadbb5a3d5a34aadb2a09df7a98ec)
#         ;
#
#
#
#
#                 marker_1a56450ce69a48e75a90201f961f71a4.setIcon(icon_3089aeb02559b4e6221e208c8fa43245);
#
#
#             var marker_d643454894e5a9a2430b4307c4ffd7a3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_04c354c1564269c427e140d2dd19be83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_befbaf1b493434caace5d87f29e98c2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01984a36ed0f17088b092cb41b8834f0 = $(`&lt;div id=&quot;html_01984a36ed0f17088b092cb41b8834f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %%
# TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc0d8bf49ce4d471ff2bea3db0b5a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc0d8bf49ce4d471ff2bea3db0b5a5b = L.map(
#                 &quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce454816d4a245021426683bb5b1f23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce454816d4a245021426683bb5b1f23d.addTo(map_0dc0d8bf49ce4d471ff2bea3db0b5a5b);
#
#
#             var marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_977b1345a52abb87489ceb4b5cc44183 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_1e3b2146ca5b411ef0f542a54f123edd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad418f9c7e229eb7445a02e3c2cf2c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_414b01a7d2a4274de3bbbfbfc0fbce9f = $(`&lt;div id=&quot;html_414b01a7d2a4274de3bbbfbfc0fbce9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_ad418f9c7e229eb7445a02e3c2cf2c9f.setContent(html_414b01a7d2a4274de3bbbfbfc0fbce9f);
#
#
#
#         marker_977b1345a52abb87489ceb4b5cc44183.bindPopup(popup_ad418f9c7e229eb7445a02e3c2cf2c9f)
#         ;
#
#
#
#
#                 marker_977b1345a52abb87489ceb4b5cc44183.setIcon(icon_1e3b2146ca5b411ef0f542a54f123edd);
#
#
#             var marker_1a56450ce69a48e75a90201f961f71a4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_3089aeb02559b4e6221e208c8fa43245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c26fadbb5a3d5a34aadb2a09df7a98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df75d921d263529f54a27229a2e2e2ea = $(`&lt;div id=&quot;html_df75d921d263529f54a27229a2e2e2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_c26fadbb5a3d5a34aadb2a09df7a98ec.setContent(html_df75d921d263529f54a27229a2e2e2ea);
#
#
#
#         marker_1a56450ce69a48e75a90201f961f71a4.bindPopup(popup_c26fadbb5a3d5a34aadb2a09df7a98ec)
#         ;
#
#
#
#
#                 marker_1a56450ce69a48e75a90201f961f71a4.setIcon(icon_3089aeb02559b4e6221e208c8fa43245);
#
#
#             var marker_d643454894e5a9a2430b4307c4ffd7a3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_04c354c1564269c427e140d2dd19be83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_befbaf1b49343

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# *TODO:* Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
launch_site_lat = 28.56316 
launch_site_lon = -80.57682
coastline_lat = 28.56316
coastline_lon = -80.56786
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)
distance_coastline
# Out:
# 0.8753213507330786

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
distance_marker = folium.Marker(
    location = (coastline_lat, coastline_lon),
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
        )
    )
site_map.add_child(distance_marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc0d8bf49ce4d471ff2bea3db0b5a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc0d8bf49ce4d471ff2bea3db0b5a5b = L.map(
#                 &quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce454816d4a245021426683bb5b1f23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce454816d4a245021426683bb5b1f23d.addTo(map_0dc0d8bf49ce4d471ff2bea3db0b5a5b);
#
#
#             var marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_977b1345a52abb87489ceb4b5cc44183 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_1e3b2146ca5b411ef0f542a54f123edd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad418f9c7e229eb7445a02e3c2cf2c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_414b01a7d2a4274de3bbbfbfc0fbce9f = $(`&lt;div id=&quot;html_414b01a7d2a4274de3bbbfbfc0fbce9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_ad418f9c7e229eb7445a02e3c2cf2c9f.setContent(html_414b01a7d2a4274de3bbbfbfc0fbce9f);
#
#
#
#         marker_977b1345a52abb87489ceb4b5cc44183.bindPopup(popup_ad418f9c7e229eb7445a02e3c2cf2c9f)
#         ;
#
#
#
#
#                 marker_977b1345a52abb87489ceb4b5cc44183.setIcon(icon_1e3b2146ca5b411ef0f542a54f123edd);
#
#
#             var marker_1a56450ce69a48e75a90201f961f71a4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_3089aeb02559b4e6221e208c8fa43245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c26fadbb5a3d5a34aadb2a09df7a98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df75d921d263529f54a27229a2e2e2ea = $(`&lt;div id=&quot;html_df75d921d263529f54a27229a2e2e2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_c26fadbb5a3d5a34aadb2a09df7a98ec.setContent(html_df75d921d263529f54a27229a2e2e2ea);
#
#
#
#         marker_1a56450ce69a48e75a90201f961f71a4.bindPopup(popup_c26fadbb5a3d5a34aadb2a09df7a98ec)
#         ;
#
#
#
#
#                 marker_1a56450ce69a48e75a90201f961f71a4.setIcon(icon_3089aeb02559b4e6221e208c8fa43245);
#
#
#             var marker_d643454894e5a9a2430b4307c4ffd7a3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_04c354c1564269c427e140d2dd19be83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_befbaf1b49343

# %% [markdown]
# *TODO:* Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
coordinates = [[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]]
lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc0d8bf49ce4d471ff2bea3db0b5a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc0d8bf49ce4d471ff2bea3db0b5a5b = L.map(
#                 &quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce454816d4a245021426683bb5b1f23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce454816d4a245021426683bb5b1f23d.addTo(map_0dc0d8bf49ce4d471ff2bea3db0b5a5b);
#
#
#             var marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_977b1345a52abb87489ceb4b5cc44183 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_1e3b2146ca5b411ef0f542a54f123edd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad418f9c7e229eb7445a02e3c2cf2c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_414b01a7d2a4274de3bbbfbfc0fbce9f = $(`&lt;div id=&quot;html_414b01a7d2a4274de3bbbfbfc0fbce9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_ad418f9c7e229eb7445a02e3c2cf2c9f.setContent(html_414b01a7d2a4274de3bbbfbfc0fbce9f);
#
#
#
#         marker_977b1345a52abb87489ceb4b5cc44183.bindPopup(popup_ad418f9c7e229eb7445a02e3c2cf2c9f)
#         ;
#
#
#
#
#                 marker_977b1345a52abb87489ceb4b5cc44183.setIcon(icon_1e3b2146ca5b411ef0f542a54f123edd);
#
#
#             var marker_1a56450ce69a48e75a90201f961f71a4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_3089aeb02559b4e6221e208c8fa43245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c26fadbb5a3d5a34aadb2a09df7a98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df75d921d263529f54a27229a2e2e2ea = $(`&lt;div id=&quot;html_df75d921d263529f54a27229a2e2e2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_c26fadbb5a3d5a34aadb2a09df7a98ec.setContent(html_df75d921d263529f54a27229a2e2e2ea);
#
#
#
#         marker_1a56450ce69a48e75a90201f961f71a4.bindPopup(popup_c26fadbb5a3d5a34aadb2a09df7a98ec)
#         ;
#
#
#
#
#                 marker_1a56450ce69a48e75a90201f961f71a4.setIcon(icon_3089aeb02559b4e6221e208c8fa43245);
#
#
#             var marker_d643454894e5a9a2430b4307c4ffd7a3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_04c354c1564269c427e140d2dd19be83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_befbaf1b49343

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# *TODO:* Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site
launch_site_lat = 28.56316 
launch_site_lon = -80.57682
highway_lat = 28.56316
highway_lon = -80.56786
distance_highway = calculate_distance(launch_site_lat, launch_site_lon, highway_lat, highway_lon)

distance_marker = folium.Marker(
    location = (highway_lat, highway_lon),
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway),
        )
    )
site_map.add_child(distance_marker)

coordinates = [[launch_site_lat, launch_site_lon], [highway_lat, highway_lon]]
lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc0d8bf49ce4d471ff2bea3db0b5a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc0d8bf49ce4d471ff2bea3db0b5a5b = L.map(
#                 &quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce454816d4a245021426683bb5b1f23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce454816d4a245021426683bb5b1f23d.addTo(map_0dc0d8bf49ce4d471ff2bea3db0b5a5b);
#
#
#             var marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_977b1345a52abb87489ceb4b5cc44183 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_1e3b2146ca5b411ef0f542a54f123edd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad418f9c7e229eb7445a02e3c2cf2c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_414b01a7d2a4274de3bbbfbfc0fbce9f = $(`&lt;div id=&quot;html_414b01a7d2a4274de3bbbfbfc0fbce9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_ad418f9c7e229eb7445a02e3c2cf2c9f.setContent(html_414b01a7d2a4274de3bbbfbfc0fbce9f);
#
#
#
#         marker_977b1345a52abb87489ceb4b5cc44183.bindPopup(popup_ad418f9c7e229eb7445a02e3c2cf2c9f)
#         ;
#
#
#
#
#                 marker_977b1345a52abb87489ceb4b5cc44183.setIcon(icon_1e3b2146ca5b411ef0f542a54f123edd);
#
#
#             var marker_1a56450ce69a48e75a90201f961f71a4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_3089aeb02559b4e6221e208c8fa43245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c26fadbb5a3d5a34aadb2a09df7a98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df75d921d263529f54a27229a2e2e2ea = $(`&lt;div id=&quot;html_df75d921d263529f54a27229a2e2e2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_c26fadbb5a3d5a34aadb2a09df7a98ec.setContent(html_df75d921d263529f54a27229a2e2e2ea);
#
#
#
#         marker_1a56450ce69a48e75a90201f961f71a4.bindPopup(popup_c26fadbb5a3d5a34aadb2a09df7a98ec)
#         ;
#
#
#
#
#                 marker_1a56450ce69a48e75a90201f961f71a4.setIcon(icon_3089aeb02559b4e6221e208c8fa43245);
#
#
#             var marker_d643454894e5a9a2430b4307c4ffd7a3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_04c354c1564269c427e140d2dd19be83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_befbaf1b49343

# %%
launch_site_lat = 28.56316 
launch_site_lon = -80.57682
rail_lat = 28.57117
rail_lon = -80.58539
distance_rail = calculate_distance(launch_site_lat, launch_site_lon, rail_lat, rail_lon)

distance_marker = folium.Marker(
    location = (rail_lat, rail_lon),
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_rail),
        )
    )
site_map.add_child(distance_marker)

coordinates = [[launch_site_lat, launch_site_lon], [rail_lat, rail_lon]]
lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc0d8bf49ce4d471ff2bea3db0b5a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc0d8bf49ce4d471ff2bea3db0b5a5b = L.map(
#                 &quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce454816d4a245021426683bb5b1f23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce454816d4a245021426683bb5b1f23d.addTo(map_0dc0d8bf49ce4d471ff2bea3db0b5a5b);
#
#
#             var marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_977b1345a52abb87489ceb4b5cc44183 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_1e3b2146ca5b411ef0f542a54f123edd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad418f9c7e229eb7445a02e3c2cf2c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_414b01a7d2a4274de3bbbfbfc0fbce9f = $(`&lt;div id=&quot;html_414b01a7d2a4274de3bbbfbfc0fbce9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_ad418f9c7e229eb7445a02e3c2cf2c9f.setContent(html_414b01a7d2a4274de3bbbfbfc0fbce9f);
#
#
#
#         marker_977b1345a52abb87489ceb4b5cc44183.bindPopup(popup_ad418f9c7e229eb7445a02e3c2cf2c9f)
#         ;
#
#
#
#
#                 marker_977b1345a52abb87489ceb4b5cc44183.setIcon(icon_1e3b2146ca5b411ef0f542a54f123edd);
#
#
#             var marker_1a56450ce69a48e75a90201f961f71a4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_3089aeb02559b4e6221e208c8fa43245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c26fadbb5a3d5a34aadb2a09df7a98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df75d921d263529f54a27229a2e2e2ea = $(`&lt;div id=&quot;html_df75d921d263529f54a27229a2e2e2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_c26fadbb5a3d5a34aadb2a09df7a98ec.setContent(html_df75d921d263529f54a27229a2e2e2ea);
#
#
#
#         marker_1a56450ce69a48e75a90201f961f71a4.bindPopup(popup_c26fadbb5a3d5a34aadb2a09df7a98ec)
#         ;
#
#
#
#
#                 marker_1a56450ce69a48e75a90201f961f71a4.setIcon(icon_3089aeb02559b4e6221e208c8fa43245);
#
#
#             var marker_d643454894e5a9a2430b4307c4ffd7a3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_04c354c1564269c427e140d2dd19be83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_befbaf1b49343

# %%
launch_site_lat = 28.57339 
launch_site_lon = -80.64762
city_lat = 28.57082
city_lon = -80.80017
distance_city = calculate_distance(launch_site_lat, launch_site_lon, city_lat, city_lon)

distance_marker = folium.Marker(
    location = (city_lat, city_lon),
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city),
        )
    )
site_map.add_child(distance_marker)

coordinates = [[launch_site_lat, launch_site_lon], [city_lat, city_lon]]
lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dc0d8bf49ce4d471ff2bea3db0b5a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dc0d8bf49ce4d471ff2bea3db0b5a5b = L.map(
#                 &quot;map_0dc0d8bf49ce4d471ff2bea3db0b5a5b&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce454816d4a245021426683bb5b1f23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce454816d4a245021426683bb5b1f23d.addTo(map_0dc0d8bf49ce4d471ff2bea3db0b5a5b);
#
#
#             var marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_977b1345a52abb87489ceb4b5cc44183 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_1e3b2146ca5b411ef0f542a54f123edd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad418f9c7e229eb7445a02e3c2cf2c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_414b01a7d2a4274de3bbbfbfc0fbce9f = $(`&lt;div id=&quot;html_414b01a7d2a4274de3bbbfbfc0fbce9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_ad418f9c7e229eb7445a02e3c2cf2c9f.setContent(html_414b01a7d2a4274de3bbbfbfc0fbce9f);
#
#
#
#         marker_977b1345a52abb87489ceb4b5cc44183.bindPopup(popup_ad418f9c7e229eb7445a02e3c2cf2c9f)
#         ;
#
#
#
#
#                 marker_977b1345a52abb87489ceb4b5cc44183.setIcon(icon_1e3b2146ca5b411ef0f542a54f123edd);
#
#
#             var marker_1a56450ce69a48e75a90201f961f71a4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_3089aeb02559b4e6221e208c8fa43245 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c26fadbb5a3d5a34aadb2a09df7a98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df75d921d263529f54a27229a2e2e2ea = $(`&lt;div id=&quot;html_df75d921d263529f54a27229a2e2e2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CCAFS LC-40&#x27;, 0]&lt;/div&gt;`)[0];
#                 popup_c26fadbb5a3d5a34aadb2a09df7a98ec.setContent(html_df75d921d263529f54a27229a2e2e2ea);
#
#
#
#         marker_1a56450ce69a48e75a90201f961f71a4.bindPopup(popup_c26fadbb5a3d5a34aadb2a09df7a98ec)
#         ;
#
#
#
#
#                 marker_1a56450ce69a48e75a90201f961f71a4.setIcon(icon_3089aeb02559b4e6221e208c8fa43245);
#
#
#             var marker_d643454894e5a9a2430b4307c4ffd7a3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_d2b2d1afaa7dd04fa0d8f0c5f2a873c6);
#
#
#             var icon_04c354c1564269c427e140d2dd19be83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;white&quot;,
#   &quot;iconColor&quot;: &quot;red&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_befbaf1b49343

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
#
# *   Are launch sites in close proximity to railways?
# *   Are launch sites in close proximity to highways?
# *   Are launch sites in close proximity to coastline?
# *   Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Pratiksha Verma](https://www.linkedin.com/in/pratiksha-verma-6487561b1/)

# %% [markdown]
# <!--## Change Log--!>

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By      | Change Description      |
# | ----------------- | ------- | -------------   | ----------------------- |
# | 2022-11-09        | 1.0     | Pratiksha Verma | Converted initial version to Jupyterlite|--!>

# %% [markdown]
# ### <h3 align="center"> IBM Corporation 2022. All rights reserved. <h3/>
